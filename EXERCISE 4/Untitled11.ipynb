# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# Step 1: Load the dataset
file_path = r"C:\Users\heman\OneDrive\Desktop\abdul\TSA\EX 6\Crude Oil Prices Daily.xlsx"
df = pd.read_excel(file_path)

# Step 2: Rename columns if needed
df.columns = ['Date', 'Price']
df['Date'] = pd.to_datetime(df['Date'])

# Step 3: Sort and set date as index
df = df.sort_values('Date')
df.set_index('Date', inplace=True)

# Step 4: Resample to monthly frequency (optional but helps with seasonality)
monthly_data = df['Price'].resample('M').mean()

# Step 5: Decompose the time series
decomposition = seasonal_decompose(monthly_data, model='additive', period=12)

# Step 6: Plot the decomposed components
plt.figure(figsize=(14, 10))

plt.subplot(411)
plt.plot(monthly_data, label='Original')
plt.title('Original Time Series')
plt.grid()

plt.subplot(412)
plt.plot(decomposition.trend, label='Trend', color='orange')
plt.title('Trend')
plt.grid()

plt.subplot(413)
plt.plot(decomposition.seasonal, label='Seasonality', color='green')
plt.title('Seasonality')
plt.grid()

plt.subplot(414)
plt.plot(decomposition.resid, label='Residuals', color='red')
plt.title('Residuals')
plt.grid()

plt.tight_layout()
plt.show()
# Out:
# C:\Users\heman\AppData\Local\Temp\ipykernel_17864\1421096348.py:18: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_data = df['Price'].resample('M').mean()
